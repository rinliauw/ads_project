# %% [markdown]
# ### Import Data

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ignore warning
import warnings
warnings.filterwarnings("ignore")

# %%
# load data
jan = pd.read_csv("../preprocessed_data/January.csv")
feb = pd.read_csv("../preprocessed_data/February.csv")
mar = pd.read_csv("../preprocessed_data/March.csv")
jan_2020 = pd.read_csv("../preprocessed_data/January_2020.csv")
feb_2020 = pd.read_csv("../preprocessed_data/February_2020.csv")
mar_2020 = pd.read_csv("../preprocessed_data/March_2020.csv")

# %%
# choose which features are correlated

jan = pd.read_csv("../raw_data/yellow_tripdata_2020-01.csv")
feb = pd.read_csv("../raw_data/yellow_tripdata_2020-02.csv")
mar = pd.read_csv("../raw_data/yellow_tripdata_2020-03.csv")

# %%
# make 
jan.head()
time_traveled = jan['tpep_dropoff_datetime'].astype('') - jan['tpep_pickup_datetime'].astype('')
time_traveled
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_223958/3648066490.py in <module>
#       1 # make
#       2 jan.head()
# ----> 3 time_traveled = jan['tpep_dropoff_datetime'].astype('') - jan['tpep_pickup_datetime'].astype('')
#       4 time_traveled
#
# /opt/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5804         else:
#    5805             # else, only a single dtype is given
# -> 5806             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5807             return self._constructor(new_data).__finalize__(self, method="astype")
#    5808
#
# /opt/miniconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     412
#     413     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 414         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     415
#     416     def convert(
#
# /opt/miniconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# /opt/miniconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     590         values = self.values
#     591
# --> 592         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     593
#     594         new_values = maybe_coerce_values(new_values)
#
# /opt/miniconda3/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1295         raise TypeError(msg)
#    1296
# -> 1297     dtype = pandas_dtype(dtype)
#    1298
#    1299     try:
#
# /opt/miniconda3/lib/python3.8/site-packages/pandas/core/dtypes/common.py in pandas_dtype(dtype)
#    1774     # raise a consistent TypeError if failed
#    1775     try:
# -> 1776         npdtype = np.dtype(dtype)
#    1777     except SyntaxError as err:
#    1778         # np.dtype uses `eval` which can raise SyntaxError
#
# TypeError: data type '' not understood

# %%
feb

# %%
mar

# %%
jan.shape

# %%
import geopandas as gpd

# sf stands for shape file
# code is taken from https://github.com/akiratwang/MAST30034_Python Lab2_Python
sf = gpd.read_file("../taxi_data/taxi_zones.shp")
zone = pd.read_csv("../taxi_data/taxi+_zone_lookup.csv")
sf['geometry'] = sf['geometry'].to_crs("+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs")

# %%
jan = pd.read_csv("../raw_data/January.csv")
feb = pd.read_csv("../raw_data/February.csv")
mar = pd.read_csv("../preprocessed_data/March.csv")

# %%
# concatenate january - march 2019
frames_2019 = [jan, feb, mar]
taxi_2019 = pd.concat(frames_2019)

# concatenate january - march 2020
frames_2020 = [jan_2020, feb_2020, mar_2020]
taxi_2020 = pd.concat(frames_2020)

taxi_2019

#extra
#is_rush_hour
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1             1.0  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2             1.0  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3             1.0  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4             2.0  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
# ...           ...                  ...                   ...              ...
# 3007287       NaN  2020-03-31 23:21:00   2020-03-31 23:33:00              NaN
# 3007288       NaN  2020-03-31 23:57:00   2020-04-01 00:26:00              NaN
# 3007289       NaN  2020-03-31 23:22:01   2020-03-31 23:43:52              NaN
# 3007290       NaN  2020-03-31 23:18:53   2020-03-31 23:32:21              NaN
# 3007291       NaN  2020-03-31 23:11:00   2020-03-31 23:30:00              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 1.20         1.0                  N           238
# 1                 1.20         1.0                  N           239
# 2                 0.60         1.0                  N           238
# 3                 0.80         1.0                  N           238
# 4                 0.00         1.0                  N           193
# ...                ...         ...                ...           ...
# 3007287           5.43         NaN                NaN           137
# 3007288          13.21         NaN                NaN           137
# 3007289          12.14         NaN                NaN           137
# 3007290           7.01         NaN                NaN           137
# 3007291           6.31         NaN                NaN           185
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                 239           1.0         6.00    3.0      0.5        1.47
# 1                 238           1.0         7.00    3.0      0.5        1.50
# 2                 238           1.0         6.00    3.0      0.5        1.00
# 3                 151           1.0         5.50    0.5      0.5        1.36
# 4                 193           2.0         3.50    0.5      0.5        0.00
# ...               ...           ...          ...    ...      ...         ...
# 3007287            87           NaN        30.47    0.0      0.5        0.00
# 3007288            71           NaN        37.97    0.0      0.5        0.00
# 3007289            32           NaN        37.10    0.0      0.0        0.00
# 3007290           159           NaN        20.07    0.0      0.0        0.00
# 3007291            69           NaN        23.40    0.0      0.5        0.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                 0.0                    0.3         11.27
# 1                 0.0                    0.3         12.30
# 2                 0.0                    0.3         10.80
# 3                 0.0                    0.3          8.16
# 4                 0.0                    0.3          4.80
# ...               ...                    ...           ...
# 3007287           0.0                    0.3         33.77
# 3007288           0.0                    0.3         41.27
# 3007289           0.0                    0.3         39.90
# 3007290           0.0                    0.3         22.87
# 3007291           0.0                    0.3         24.20
#
#          congestion_surcharge
# 0                         2.5
# 1                         2.5
# 2                         2.5
# 3                         0.0
# 4                         0.0
# ...                       ...
# 3007287                   2.5
# 3007288                   2.5
# 3007289                   2.5
# 3007290                   2.5
# 3007291                   0.0
#
# [15711654 rows x 18 columns]

# %%
taxi_2019.dtypes
# Out:
# Unnamed: 0                                        int64
# VendorID                                          int64
# tpep_pickup_datetime                             object
# tpep_dropoff_datetime                            object
# passenger_count                                   int64
# trip_distance                                   float64
# RatecodeID                                        int64
# store_and_fwd_flag                               object
# PULocationID                                      int64
# DOLocationID                                      int64
# payment_type                                      int64
# fare_amount                                     float64
# extra                                           float64
# mta_tax                                         float64
# tip_amount                                      float64
# tolls_amount                                    float64
# improvement_surcharge                           float64
# total_amount                                    float64
# congestion_surcharge                            float64
# taxi_datetime                                    object
# Year                                            float64
# Month                                           float64
# Day                                               int64
# Max                                               int64
# Min                                               int64
# Rain, Melted Snow, Etc. (in)                     object
# Snow, Ice, Pellets, Hail (in)                    object
# Snow, Ice, Pellets, Hail, Ice on Ground (in)     object
# weather_datetime                                 object
# weather_median                                  float64
# dtype: object

# %%
taxi_2019_x = taxi_2019[['tolls_amount', 'fare_amount', 'trip_distance', 'passenger_count', 'mta_tax']]
taxi_2019_x.dtypes
taxi_2019_y = taxi_2019['total_amount']
taxi_2019_x
# Out:
#          tolls_amount  fare_amount  trip_distance  passenger_count  mta_tax
# 0                 0.0          7.0           1.50                1      0.5
# 1                 0.0         14.0           2.60                1      0.5
# 2                 0.0          6.5           1.30                1      0.5
# 3                 0.0         13.5           3.70                1      0.5
# 4                 0.0         10.0           2.10                2      0.5
# ...               ...          ...            ...              ...      ...
# 6703761           0.0          7.0           1.38                1      0.5
# 6703762           0.0          5.0           0.99                2      0.5
# 6703763           0.0          4.5           0.75                2      0.5
# 6703764           0.0          5.5           1.17                1      0.5
# 6703765           0.0          5.5           1.11                1      0.5
#
# [19274979 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

(X_train, X_test, Y_train, Y_test) = train_test_split(taxi_2019_x, taxi_2019_y,test_size=0.2, random_state=20)

# %%
taxi_2019_y = taxi_2019_y.astype('int64')

# %%
taxi_2019_y.dtypes
# Out:
# dtype('int64')

# %%
taxi_2019_x = taxi_2019_x.astype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_223958/4223768148.py in <module>
# ----> 1 taxi_2019_x = taxi_2019_x.astype()
#
# TypeError: astype() missing 1 required positional argument: 'dtype'

# %%
c

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in /mnt/student.unimelb.edu.au/kliauw/.local/lib/python3.8/site-packages (1.4.2)
# Requirement already satisfied: numpy in /opt/miniconda3/lib/python3.8/site-packages (from xgboost) (1.21.0)
# Requirement already satisfied: scipy in /opt/miniconda3/lib/python3.8/site-packages (from xgboost) (1.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
lr = LinearRegression()
reg = lr.fit(X_train, Y_train)
reg.score(X_train, Y_train)
reg.predict(X_test)
# Out:
# array([16.56,  5.8 ,  6.24, ..., 13.56,  8.75, 14.3 ])

# %%
from sklearn.model_selection import train_test_split
def reg_modeling_split(X,Y,size) :
    # Model Collection
    models = []
    models.append(('LASSO', Lasso()))
    models.append(('EN', ElasticNet()))
    # models.append(('KNN', KNeighborsRegressor()))
    # models.append(('CART', DecisionTreeRegressor()))
    # models.append(('XGB', XGBRegressor()))
    models.append(('LinearRegression', LinearRegression()))
    # Initial Values
    results = []
    best_result = []
    names = []
    scoring = 'neg_mean_squared_error'
    cur_score = -1000
    runtime = []
    # Evaluate Each Model and Select Best Model
    for i, (name, model) in enumerate(models):
        # Cross Validation k-Fold
        seed = 7
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=size,random_state=seed)
        t0 = time()
        cv_results = cross_val_score(model, X_train, Y_train, cv=3, scoring=scoring)
        print("%s: %f in %.3f" % (name,cv_results.mean(),time()-t0))
        runtime.append(time() - t0)
        results.append(cv_results.mean())
        names.append(name)    
        # Best Model Selection
        if cv_results.mean() > cur_score:
            cur_score = cv_results.mean()
            best_result = cv_results
            best_index = i
            print("Better Model %s: %f in %.3f" % (name,cv_results.mean(),time()-t0))
    best_model = models[best_index]
    best_time = runtime[best_index]
    return (best_model,best_time,best_result)

best_model = reg_modeling_split(taxi_2019_x.values, taxi_2019_y.values, 0.2)
# Out:
# LASSO: -227.716353 in 3.042
# Better Model LASSO: -227.716353 in 3.043
# EN: -220.200069 in 3.113
# Better Model EN: -220.200069 in 3.114
# LinearRegression: -144.163406 in 3.652
# Better Model LinearRegression: -144.163406 in 3.652

# %%
taxi_2019_y.describe()
# Out:
# count    1.927498e+07
# mean     1.377412e+01
# std      1.420987e+02
# min      3.100000e-01
# 25%      9.800000e+00
# 50%      1.274000e+01
# 75%      1.656000e+01
# max      6.232617e+05
# Name: total_amount, dtype: float64

# %%
model = best_model[0][1]
jan_2020_x = jan_2020[['tolls_amount', 'fare_amount', 'trip_distance', 'passenger_count', 'mta_tax']]
jan_2020_y = jan_2020['total_amount']
jan_2020_pred = model.predict(jan_2020_x)

# %%
def reg_modeling(X,Y,fold) :
    # Model Collection
    models = []
    models.append(('LASSO', Lasso()))
    models.append(('EN', ElasticNet()))
    models.append(('KNN', KNeighborsRegressor()))
    models.append(('CART', DecisionTreeRegressor()))
    models.append(('XGB', XGBRegressor()))
    # Initial Values
    results = []
    best_result = []
    names = []
    scoring = 'neg_mean_squared_error'
    cur_score = -1000
    runtime = []
    # Evaluate Each Model and Select Best Model
    for i, (name, model) in enumerate(models):
        # Cross Validation k-Fold
        kfold = KFold(n_splits=fold, shuffle= True, random_state=7)
        t0 = time()
        cv_results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
        print("%s: %f in %.3f" % (name,cv_results.mean(),time()-t0))
        runtime.append(time() - t0)
        results.append(cv_results.mean())
        names.append(name)    
        # Best Model Selection
        if cv_results.mean() > cur_score:
            cur_score = cv_results.mean()
            best_result = cv_results
            best_index = i
            print("Better Model %s: %f in %.3f" % (name,cv_results.mean(),time()-t0))
    best_model = models[best_index]
    best_time = runtime[best_index]
    return (best_model,best_time,best_result)

reg_modeling(taxi_2019_x.values, taxi_2019_y.values, 5)

# %%
taxi_2019['tolls_amount'].describe()
# Out:
# count    1.927498e+07
# mean     1.911212e-02
# std      5.028338e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      7.666600e+02
# Name: tolls_amount, dtype: float64

# %%
taxi_2020
# Out:
#          Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20
# 1                 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59
# 2                 2         1  2019-01-01 00:21:28   2019-01-01 00:28:37
# 3                 3         1  2019-01-01 00:32:01   2019-01-01 00:45:39
# 4                 4         1  2019-01-01 00:57:32   2019-01-01 01:09:32
# ...             ...       ...                  ...                   ...
# 6703761     7832390         2  2019-03-31 23:17:04   2019-03-31 23:23:46
# 6703762     7832392         2  2019-03-31 23:00:55   2019-03-31 23:04:58
# 6703763     7832393         2  2019-03-31 23:19:33   2019-03-31 23:22:55
# 6703764     7832394         2  2019-03-31 23:35:19   2019-03-31 23:39:30
# 6703765     7832396         2  2019-03-31 23:20:15   2019-03-31 23:24:12
#
#          passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                      1           1.50           1                  N
# 1                      1           2.60           1                  N
# 2                      1           1.30           1                  N
# 3                      1           3.70           1                  N
# 4                      2           2.10           1                  N
# ...                  ...            ...         ...                ...
# 6703761                1           1.38           1                  N
# 6703762                2           0.99           1                  N
# 6703763                2           0.75           1                  N
# 6703764                1           1.17           1                  N
# 6703765                1           1.11           1                  N
#
#          PULocationID  DOLocationID  ...    Year  Month  Day  Max  Min  \
# 0                 151           239  ...  2019.0    1.0    1   58   39
# 1                 239           246  ...  2019.0    1.0    1   58   39
# 2                 163           229  ...  2019.0    1.0    1   58   39
# 3                 229             7  ...  2019.0    1.0    1   58   39
# 4                 141           234  ...  2019.0    1.0    1   58   39
# ...               ...           ...  ...     ...    ...  ...  ...  ...
# 6703761           100           107  ...  2019.0    3.0   31   65   39
# 6703762           230           230  ...  2019.0    3.0   31   65   39
# 6703763            48           230  ...  2019.0    3.0   31   65   39
# 6703764           100           249  ...  2019.0    3.0   31   65   39
# 6703765           263           236  ...  2019.0    3.0   31   65   39
#
#          Rain, Melted Snow, Etc. (in)  Snow, Ice, Pellets, Hail (in)  \
# 0                                0,06                              0
# 1                                0,06                              0
# 2                                0,06                              0
# 3                                0,06                              0
# 4                                0,06                              0
# ...                               ...                            ...
# 6703761                          0,06                              0
# 6703762                          0,06                              0
# 6703763                          0,06                              0
# 6703764                          0,06                              0
# 6703765                          0,06                              0
#
#          Snow, Ice, Pellets, Hail, Ice on Ground (in)     weather_datetime  \
# 0                                                   0  2019-01-01 00:00:00
# 1                                                   0  2019-01-01 00:00:00
# 2                                                   0  2019-01-01 00:00:00
# 3                                                   0  2019-01-01 00:00:00
# 4                                                   0  2019-01-01 00:00:00
# ...                                               ...                  ...
# 6703761                                             0  2019-03-31 00:00:00
# 6703762                                             0  2019-03-31 00:00:00
# 6703763                                             0  2019-03-31 00:00:00
# 6703764                                             0  2019-03-31 00:00:00
# 6703765                                             0  2019-03-31 00:00:00
#
#         weather_median
# 0                 48.5
# 1                 48.5
# 2                 48.5
# 3                 48.5
# 4                 48.5
# ...                ...
# 6703761           52.0
# 6703762           52.0
# 6703763           52.0
# 6703764           52.0
# 6703765           52.0
#
# [19274979 rows x 30 columns]

# %% [markdown]
# ## Heat Map

# %%
# graph 1: make heat map
heat_map = taxi_2019
heat_map = heat_map.drop(columns = ["VendorID"])
plt.subplots(figsize=(15, 10))
sns.heatmap(heat_map.corr(), annot = True)
plt.savefig("../plots/heat_map.png")

# %% [markdown]
# ## Geo-spatial Figures

# %%
# graph 2: make geo-spatial maps

# %%
# make random graph
